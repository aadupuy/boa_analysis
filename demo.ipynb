# %%
from core.streamiter import plot_stream_iterations

plot_stream_iterations()

# %%
from core.step import plot_step_comparison

plot_step_comparison()

# %%
from core.thresholdmax import plot_threshold_comparison

plot_threshold_comparison()
# Out:
# 5000: 3.05% missing regions
# 50000: 42.14% missing regions

# %%
from core.convergence import plot_convergence

plot_convergence()

# %%
from analysis.number_basins import plot_n_basins_vs_smoothing

plot_n_basins_vs_smoothing()

# %%
from visualization.visualizations_rs import plot_boa_vs_smoothing

plot_boa_vs_smoothing()

# %%
from visualization.visualizations_z import plot_boa_vs_redshift

plot_boa_vs_redshift()

# %%
from visualization.visualizations_resolution import plot_boa_vs_resolution

plot_boa_vs_resolution()
